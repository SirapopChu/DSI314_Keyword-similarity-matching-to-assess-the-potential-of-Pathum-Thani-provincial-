# %% [markdown]
# **LLama-70b**

# %%
import requests
import json

# %%
from openai import OpenAI

client = OpenAI(base_url="https://openrouter.ai/api/v1",
api_key="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"
)

completion = client.chat.completions.create(
  model="meta-llama/llama-3.1-70b-instruct:free",
  messages=[
    {
      "role": "user",
      "content": f"""
            คุณเป็นผู้เชี่ยวชาญในการทำนโยบายและแผนงานต่างๆรวมถึงการวิเคราะห์ยุทธศาสตร์ต่างๆของภาครัฐไทยโดยเฉพาะอย่างยิ่งในจังหวัดปทุมธานี
            หากคุณต้องเลือก 10 คำจากลิสต์ต่อไปนี้
            ['เขื่อน', 'ตลิ่ง', 'ภูมิทัศน์', 'น้ํา', 'ทางหลวง', 'แม่น้ำ', 'คลอง', 'ชุมชน', 'ขยะ', 'ช่องจราจร', 'แหล่งน้ำ', 'ชลประทาน', 'วัชพืช', 'โรงงาน', 'ลําน้ํา', 'ชีวิต', 'วิถี', 'ประชาชน', 'อุตสาหกรรม', 'ลำคลอง', 'สิ่งแวดล้อม', 'ขยะมูลฝอย', 'ไฟฟ้า', 'แสงสว่าง']
            คำไหนที่สอดคล้องกับ ประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม

            เพื่อเป็นข้อมูลอ้างอิง
            ประเด็นการพัฒนาที่ 1
            มีวัตุประสงค์เพื่อ
            1.อนุรักษ์ฟื้นฟูและใช้ประโยชน์ทรัพยากรธรรมชาติและสิ่งแวดล้อมอย่างสมดุลและยั่งยืน
            2.เพื่อพัฒนาเชื่อมโยงระบบโครงข่ายการคมนาคมและระบบโลจิกติกส์ให้มีประสิทธิภาพ รองรับการขยายตัวทางเศรษฐกิจและสังคม
            มีตัวชี้วัดคือ
            1.ระดับความสำเร็จของการดำเนินการพัฒนาพื้นที่อุตสาหกรรมเข้าสู่เมืองอุตสาหกรรมเชิงนิเวศ
            2.ร้อยละของปริมาณขยะมูลฝอยชุมชนได้รับการจัดการอย่างถูกต้องตามหลักวิชาการ
            3.ร้อยละของคดีการเกิดอุบัติเหตุจราจรทางบกลดลง

        """
      }
    ]
  )

print(completion.choices[0].message.content)
# Out:
# จากประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม
#
# 10 คำที่สอดคล้องกับประเด็นการพัฒนาที่ 1 คือ
#
# 1.  สิ่งแวดล้อม
# 2.  ชุมชน
# 3.  ทางหลวง
# 4.  ช่องจราจร
# 5.  ขยะ
# 6.  ขยะมูลฝอย
# 7.  อุตสาหกรรม
# 8.  โรงงาน
# 9.  ประชาชน
# 10. ชีวิต

# %% [markdown]
# **ChatGPT-4O**

# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  model="openai/chatgpt-4o-latest",
  messages=[
    {
      "role": "user",
      "content": f"""
            คุณเป็นผู้เชี่ยวชาญในการทำนโยบายและแผนงานต่างๆรวมถึงการวิเคราะห์ยุทธศาสตร์ต่างๆของภาครัฐไทยโดยเฉพาะอย่างยิ่งในจังหวัดปทุมธานี
            หากคุณต้องเลือก 10 คำจากลิสต์ต่อไปนี้
            ['เขื่อน', 'ตลิ่ง', 'ภูมิทัศน์', 'น้ํา', 'ทางหลวง', 'แม่น้ำ', 'คลอง', 'ชุมชน', 'ขยะ', 'ช่องจราจร', 'แหล่งน้ำ', 'ชลประทาน', 'วัชพืช', 'โรงงาน', 'ลําน้ํา', 'ชีวิต', 'วิถี', 'ประชาชน', 'อุตสาหกรรม', 'ลำคลอง', 'สิ่งแวดล้อม', 'ขยะมูลฝอย', 'ไฟฟ้า', 'แสงสว่าง']
            คำไหนที่สอดคล้องกับ ประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม

            เพื่อเป็นข้อมูลอ้างอิง
            ประเด็นการพัฒนาที่ 1
            มีวัตุประสงค์เพื่อ
            1.อนุรักษ์ฟื้นฟูและใช้ประโยชน์ทรัพยากรธรรมชาติและสิ่งแวดล้อมอย่างสมดุลและยั่งยืน
            2.เพื่อพัฒนาเชื่อมโยงระบบโครงข่ายการคมนาคมและระบบโลจิกติกส์ให้มีประสิทธิภาพ รองรับการขยายตัวทางเศรษฐกิจและสังคม
            มีตัวชี้วัดคือ
            1.ระดับความสำเร็จของการดำเนินการพัฒนาพื้นที่อุตสาหกรรมเข้าสู่เมืองอุตสาหกรรมเชิงนิเวศ
            2.ร้อยละของปริมาณขยะมูลฝอยชุมชนได้รับการจัดการอย่างถูกต้องตามหลักวิชาการ
            3.ร้อยละของคดีการเกิดอุบัติเหตุจราจรทางบกลดลง

        """
      }
    ]
  )

print(completion.choices[0].message.content)

# %% [markdown]
# **Claude Sonnet**

# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  model="anthropic/claude-3.5-sonnet:beta",
  messages=[
    {
      "role": "user",
      "content": f"""
            คุณเป็นผู้เชี่ยวชาญในการทำนโยบายและแผนงานต่างๆรวมถึงการวิเคราะห์ยุทธศาสตร์ต่างๆของภาครัฐไทยโดยเฉพาะอย่างยิ่งในจังหวัดปทุมธานี
            หากคุณต้องเลือก 10 คำจากลิสต์ต่อไปนี้
            ['เขื่อน', 'ตลิ่ง', 'ภูมิทัศน์', 'น้ํา', 'ทางหลวง', 'แม่น้ำ', 'คลอง', 'ชุมชน', 'ขยะ', 'ช่องจราจร', 'แหล่งน้ำ', 'ชลประทาน', 'วัชพืช', 'โรงงาน', 'ลําน้ํา', 'ชีวิต', 'วิถี', 'ประชาชน', 'อุตสาหกรรม', 'ลำคลอง', 'สิ่งแวดล้อม', 'ขยะมูลฝอย', 'ไฟฟ้า', 'แสงสว่าง']
            คำไหนที่สอดคล้องกับ ประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม

            เพื่อเป็นข้อมูลอ้างอิง
            ประเด็นการพัฒนาที่ 1
            มีวัตุประสงค์เพื่อ
            1.อนุรักษ์ฟื้นฟูและใช้ประโยชน์ทรัพยากรธรรมชาติและสิ่งแวดล้อมอย่างสมดุลและยั่งยืน
            2.เพื่อพัฒนาเชื่อมโยงระบบโครงข่ายการคมนาคมและระบบโลจิกติกส์ให้มีประสิทธิภาพ รองรับการขยายตัวทางเศรษฐกิจและสังคม
            มีตัวชี้วัดคือ
            1.ระดับความสำเร็จของการดำเนินการพัฒนาพื้นที่อุตสาหกรรมเข้าสู่เมืองอุตสาหกรรมเชิงนิเวศ
            2.ร้อยละของปริมาณขยะมูลฝอยชุมชนได้รับการจัดการอย่างถูกต้องตามหลักวิชาการ
            3.ร้อยละของคดีการเกิดอุบัติเหตุจราจรทางบกลดลง

        """
      }
    ]
  )
print(completion.choices[0].message.content)

# %% [markdown]
# **Typhoon-70b**

# %%
from openai import OpenAI
client = OpenAI(
   api_key='sk-hMyKjhlp2CVH1G4EGdwQ7asMYS44cEbTWYHmWTNJPUzCJtku',
   base_url='https://api.opentyphoon.ai/v1'
)

chat_completion = client.chat.completions.create(
    model="typhoon-v1.5x-70b-instruct",
    messages=[{"role": "user", "content":  f"""
            คุณเป็นผู้เชี่ยวชาญในการทำนโยบายและแผนงานต่างๆรวมถึงการวิเคราะห์ยุทธศาสตร์ต่างๆของภาครัฐไทยโดยเฉพาะอย่างยิ่งในจังหวัดปทุมธานี
            หากคุณต้องเลือก 10 คำจากลิสต์ต่อไปนี้
            ['เขื่อน', 'ตลิ่ง', 'ภูมิทัศน์', 'น้ํา', 'ทางหลวง', 'แม่น้ำ', 'คลอง', 'ชุมชน', 'ขยะ', 'ช่องจราจร', 'แหล่งน้ำ', 'ชลประทาน', 'วัชพืช', 'โรงงาน', 'ลําน้ํา', 'ชีวิต', 'วิถี', 'ประชาชน', 'อุตสาหกรรม', 'ลำคลอง', 'สิ่งแวดล้อม', 'ขยะมูลฝอย', 'ไฟฟ้า', 'แสงสว่าง']
            คำไหนที่สอดคล้องกับ ประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม

            เพื่อเป็นข้อมูลอ้างอิง
            ประเด็นการพัฒนาที่ 1
            มีวัตุประสงค์เพื่อ
            1.อนุรักษ์ฟื้นฟูและใช้ประโยชน์ทรัพยากรธรรมชาติและสิ่งแวดล้อมอย่างสมดุลและยั่งยืน
            2.เพื่อพัฒนาเชื่อมโยงระบบโครงข่ายการคมนาคมและระบบโลจิกติกส์ให้มีประสิทธิภาพ รองรับการขยายตัวทางเศรษฐกิจและสังคม
            มีตัวชี้วัดคือ
            1.ระดับความสำเร็จของการดำเนินการพัฒนาพื้นที่อุตสาหกรรมเข้าสู่เมืองอุตสาหกรรมเชิงนิเวศ
            2.ร้อยละของปริมาณขยะมูลฝอยชุมชนได้รับการจัดการอย่างถูกต้องตามหลักวิชาการ
            3.ร้อยละของคดีการเกิดอุบัติเหตุจราจรทางบกลดลง

        """}]
)
print(chat_completion.choices[0].message.content)
# Out:
# จากลิสต์คำที่ให้มา, 10 คำที่สอดคล้องกับประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม ได้แก่:
#
# 1. ภูมิทัศน์
# 2. น้ํา
# 3. ทางหลวง
# 4. ชุมชน
# 5. ขยะ
# 6. ช่องจราจร
# 7. แหล่งน้ำ
# 8. สิ่งแวดล้อม
# 9. ขยะมูลฝอย
# 10. ไฟฟ้า
#
# คำเหล่านี้สอดคล้องกับวัตถุประสงค์และตัวชี้วัดของประเด็นการพัฒนาที่ 1 ซึ่งเน้นที่การอนุรักษ์ฟื้นฟูและใช้ประโยชน์ทรัพยากรธรรมชาติและสิ่งแวดล้อม, การพัฒนาเชื่อมโยงระบบโครงข่ายการคมนาคมและระบบโลจิกติกส์, และการจัดการขยะมูลฝอยชุมชนอย่างถูกต้องตามหลักวิชาการ.

# %% [markdown]
# **OpenThaiGPT**

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

messages = [
    {"role": "user", "content": f"""
            คุณเป็นผู้เชี่ยวชาญในการทำนโยบายและแผนงานต่างๆรวมถึงการวิเคราะห์ยุทธศาสตร์ต่างๆของภาครัฐไทยโดยเฉพาะอย่างยิ่งในจังหวัดปทุมธานี
            หากคุณต้องเลือก 10 คำจากลิสต์ต่อไปนี้
            ['เขื่อน', 'ตลิ่ง', 'ภูมิทัศน์', 'น้ํา', 'ทางหลวง', 'แม่น้ำ', 'คลอง', 'ชุมชน', 'ขยะ', 'ช่องจราจร', 'แหล่งน้ำ', 'ชลประทาน', 'วัชพืช', 'โรงงาน', 'ลําน้ํา', 'ชีวิต', 'วิถี', 'ประชาชน', 'อุตสาหกรรม', 'ลำคลอง', 'สิ่งแวดล้อม', 'ขยะมูลฝอย', 'ไฟฟ้า', 'แสงสว่าง']
            คำไหนที่สอดคล้องกับ ประเด็นการพัฒนาที่ 1 : พัฒนาสภาพแวดล้อมเมืองให้น่าอยู่ เอื้อต่อการขยายตัวทางเศรษฐกิจและสังคม

            เพื่อเป็นข้อมูลอ้างอิง
            ประเด็นการพัฒนาที่ 1
            มีวัตุประสงค์เพื่อ
            1.อนุรักษ์ฟื้นฟูและใช้ประโยชน์ทรัพยากรธรรมชาติและสิ่งแวดล้อมอย่างสมดุลและยั่งยืน
            2.เพื่อพัฒนาเชื่อมโยงระบบโครงข่ายการคมนาคมและระบบโลจิกติกส์ให้มีประสิทธิภาพ รองรับการขยายตัวทางเศรษฐกิจและสังคม
            มีตัวชี้วัดคือ
            1.ระดับความสำเร็จของการดำเนินการพัฒนาพื้นที่อุตสาหกรรมเข้าสู่เมืองอุตสาหกรรมเชิงนิเวศ
            2.ร้อยละของปริมาณขยะมูลฝอยชุมชนได้รับการจัดการอย่างถูกต้องตามหลักวิชาการ
            3.ร้อยละของคดีการเกิดอุบัติเหตุจราจรทางบกลดลง

        """},
]
pipe = pipeline("text-generation", model="openthaigpt/openthaigpt1.5-72b-instruct")
pipe(messages)
